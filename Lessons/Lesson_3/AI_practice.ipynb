# %% [markdown]
# # Практическое задание по Python - Урок 3
#
# В этом ноутбуке вы найдете упражнения для закрепления изученного материала:
# - Идентификаторы
# - Типы данных
# - Переменные
# - Операторы
#
# Выполняйте упражнения по порядку и проверяйте свои ответы!

# %% [markdown]
# ---
# ## Упражнение 1: Идентификаторы
#
# **Задание:** Определите, какие из следующих идентификаторов являются правильными, а какие - нет. Объясните почему.
#
# Список идентификаторов для проверки:
# - my_variable
# - 2nd_place
# - class
# - user_name
# - my-var
# - _private
# - True
# - myVariable
# - my_variable_2

# %%
# Протестируйте каждый идентификатор, раскомментировав строку:

my_variable = 10
# 2nd_place = 5
# class = 'Python'
# user_name = 'Ivan'
# my-var = 3
# _private = 7
# True = False
# myVariable = 15
# my_variable_2 = 20

# Ваш ответ:
Правильные идентификаторы: 
# Неправильные идентификаторы:
# Out:
#   Cell In[1], line 14
#     Правильные идентификаторы:
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---
# ## Упражнение 2: Типы данных
#
# **Задание:** Создайте переменные следующих типов и выведите их тип с помощью функции type()

# %%
# 1. Создайте переменную с целым числом (int)
# Ваш код здесь:


# 2. Создайте переменную с числом с плавающей точкой (float)
# Ваш код здесь:


# 3. Создайте переменную со строкой (str)
# Ваш код здесь:


# 4. Создайте переменную с логическим значением (bool)
# Ваш код здесь:


# Выведите тип каждой переменной:
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 3: Арифметические операторы
#
# **Задание:** Выполните следующие вычисления и выведите результат

# %%
# 1. Сложите 15 и 27
# Ваш код здесь:


# 2. Вычтите 8 из 20
# Ваш код здесь:


# 3. Умножьте 6 на 7
# Ваш код здесь:


# 4. Разделите 45 на 9
# Ваш код здесь:


# 5. Найдите остаток от деления 17 на 5
# Ваш код здесь:


# 6. Возведите 3 в степень 4
# Ваш код здесь:


# 7. Выполните целочисленное деление 19 на 4
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 4: Операторы сравнения
#
# **Задание:** Сравните следующие значения и выведите результат

# %%
# 1. Проверьте, равно ли 10 числу 10
# Ваш код здесь:


# 2. Проверьте, не равно ли 5 числу 7
# Ваш код здесь:


# 3. Проверьте, больше ли 15 числа 10
# Ваш код здесь:


# 4. Проверьте, меньше или равно ли 8 числу 8
# Ваш код здесь:


# 5. Проверьте, больше или равно ли 20 числу 25
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 5: Практическая задача - Покупки в магазине
#
# **Задание:** Представьте, что вы покупаете товары в магазине. Выполните вычисления.

# %%
# Цены товаров (используйте float)
price_apple = 50.5
price_bread = 35.0
price_milk = 89.9

# Количество каждого товара (используйте int)
quantity_apple = 3
quantity_bread = 2
quantity_milk = 1

# 1. Вычислите общую стоимость каждого товара
# Ваш код здесь:


# 2. Вычислите общую сумму покупки
# Ваш код здесь:


# 3. Если у вас есть 500 рублей, хватит ли денег на покупку?
# Используйте оператор сравнения
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 6: Порядок операций (PEMDAS)
#
# **Задание:** Вычислите следующие выражения и объясните порядок вычислений

# %%
# 1. 2 + 3 * 4
# Ваш код здесь:


# 2. (2 + 3) * 4
# Ваш код здесь:


# 3. 10 - 3 ** 2
# Ваш код здесь:


# 4. (10 - 3) ** 2
# Ваш код здесь:


# 5. 20 / 4 + 2 * 3
# Ваш код здесь:


# 6. 20 / (4 + 2) * 3
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 7: Работа со строками
#
# **Задание:** Выполните следующие операции со строками

# %%
first_name = 'Иван'
last_name = 'Иванов'

# 1. Объедините имя и фамилию через пробел
# Ваш код здесь:


# 2. Повторите имя 3 раза
# Ваш код здесь:


# 3. Проверьте, содержится ли буква 'а' в имени
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 8: Логические значения
#
# **Задание:** Создайте выражения, которые возвращают True или False

# %%
# 1. Выражение, которое возвращает True
# Ваш код здесь:


# 2. Выражение, которое возвращает False
# Ваш код здесь:


# 3. Проверьте, что 10 больше 5 И 20 меньше 30
# (используйте оператор and)
# Ваш код здесь:


# 4. Проверьте, что 5 больше 10 ИЛИ 15 больше 10
# (используйте оператор or)
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 9: Изменение типа переменной
#
# **Задание:** Продемонстрируйте, что тип переменной можно изменить

# %%
# 1. Создайте переменную с целым числом
# Ваш код здесь:


# 2. Выведите её тип
# Ваш код здесь:


# 3. Присвойте этой же переменной строку
# Ваш код здесь:


# 4. Выведите её тип снова
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 10: Итоговая задача - Прямоугольник
#
# **Задание:** Вычислите площадь и периметр прямоугольника

# %%
# Дано:
length = 12.5  # длина прямоугольника
width = 7.3    # ширина прямоугольника

# 1. Вычислите площадь прямоугольника (длина * ширина)
# Ваш код здесь:


# 2. Вычислите периметр прямоугольника (2 * (длина + ширина))
# Ваш код здесь:


# 3. Округлите площадь до 2 знаков после запятой
# Подсказка: используйте round(число, количество_знаков)
# Ваш код здесь:


# 4. Выведите результаты в красивом формате
# Например: "Площадь прямоугольника: XX.XX, Периметр: XX.XX"
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 11: Дополнительная задача - Банковский вклад
#
# **Задание:** Рассчитайте, сколько денег будет на банковском вкладе через год

# %%
# Дано:
initial_amount = 10000  # начальная сумма вклада
interest_rate = 5       # процентная ставка (5%)

# 1. Вычислите сумму процентов за год
# Ваш код здесь:


# 2. Вычислите итоговую сумму на вкладе через год
# Ваш код здесь:


# 3. Округлите итоговую сумму до 2 знаков после запятой
# Ваш код здесь:


# 4. Выведите результат
# Ваш код здесь:

# %% [markdown]
# ---
# ## Упражнение 12: Дополнительная задача - Температура
#
# **Задание:** Преобразуйте температуру из Цельсия в Фаренгейты
#
# Формула: F = C * 9/5 + 32

# %%
# Дано:
celsius = 25  # температура в градусах Цельсия

# 1. Преобразуйте температуру в Фаренгейты
# Ваш код здесь:


# 2. Округлите результат до 1 знака после запятой
# Ваш код здесь:


# 3. Выведите результат
# Ваш код здесь:

# %% [markdown]
# ---
#
# ## Проверка себя
#
# После выполнения всех упражнений проверьте себя:
#
# ✅ Все ли идентификаторы названы правильно?
#
# ✅ Понимаете ли вы разницу между типами данных (int, float, str, bool)?
#
# ✅ Умеете ли вы использовать все арифметические операторы (+, -, *, /, %, **, //)?
#
# ✅ Понимаете ли вы, как работают операторы сравнения (==, !=, <, >, <=, >=)?
#
# ✅ Помните ли вы порядок операций (PEMDAS)?
#
# ✅ Умеете ли вы создавать переменные и изменять их значения?
#
# ✅ Понимаете ли вы, что Python - регистрозависимый язык?
#
# Если у вас возникли трудности с каким-либо упражнением, вернитесь к теоретическому материалу в файле python_basics.ipynb и попробуйте снова!

# %% [markdown]
# ---
#
# ## Ответы для самопроверки
#
# ### Упражнение 1: Идентификаторы
#
# **Правильные идентификаторы:**
# - my_variable ✓
# - user_name ✓
# - _private ✓
# - myVariable ✓
# - my_variable_2 ✓
#
# **Неправильные идентификаторы:**
# - 2nd_place ✗ (начинается с цифры)
# - class ✗ (зарезервированное слово)
# - my-var ✗ (содержит дефис)
# - True ✗ (зарезервированное слово)
#
# ### Упражнение 3: Арифметические операторы
#
# 1. 15 + 27 = 42
# 2. 20 - 8 = 12
# 3. 6 * 7 = 42
# 4. 45 / 9 = 5.0
# 5. 17 % 5 = 2
# 6. 3 ** 4 = 81
# 7. 19 // 4 = 4
#
# ### Упражнение 4: Операторы сравнения
#
# 1. 10 == 10 → True
# 2. 5 != 7 → True
# 3. 15 > 10 → True
# 4. 8 <= 8 → True
# 5. 20 >= 25 → False
#
# ### Упражнение 5: Покупки
#
# 1. Стоимость яблок: 50.5 * 3 = 151.5
# 2. Стоимость хлеба: 35.0 * 2 = 70.0
# 3. Стоимость молока: 89.9 * 1 = 89.9
# 4. Общая сумма: 151.5 + 70.0 + 89.9 = 311.4
# 5. 311.4 <= 500 → True (денег хватит)
#
# ### Упражнение 6: Порядок операций
#
# 1. 2 + 3 * 4 = 2 + 12 = 14
# 2. (2 + 3) * 4 = 5 * 4 = 20
# 3. 10 - 3 ** 2 = 10 - 9 = 1
# 4. (10 - 3) ** 2 = 7 ** 2 = 49
# 5. 20 / 4 + 2 * 3 = 5 + 6 = 11
# 6. 20 / (4 + 2) * 3 = 20 / 6 * 3 = 3.333... * 3 = 10.0
#
# ### Упражнение 10: Прямоугольник
#
# 1. Площадь: 12.5 * 7.3 = 91.25
# 2. Периметр: 2 * (12.5 + 7.3) = 2 * 19.8 = 39.6
# 3. Округленная площадь: 91.25
#
# ### Упражнение 11: Банковский вклад
#
# 1. Проценты: 10000 * 0.05 = 500
# 2. Итоговая сумма: 10000 + 500 = 10500
#
# ### Упражнение 12: Температура
#
# 1. F = 25 * 9/5 + 32 = 45 + 32 = 77
# 2. Округленный результат: 77.0
